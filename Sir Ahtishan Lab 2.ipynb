# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install rasterio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 57.6 MB/s eta 0:00:00
# ...

# %%
pip install geotiff
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 4.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 60.0 MB/s eta 0:00:00
# ...
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5034 sha256=c2107d240155d03d5a41e7dd165423f34988a06d5eec7fc87ec912d916ab6621
#   Stored in directory: /root/.cache/pip/wheels/7f/4e/be/1171b40f43b918087657ec57cf3b81fa1a2e027d8755baa184
# Successfully built asciitree
# ...

# %%
# import rasterio
from rasterio.plot import show
# import rasterio
import geotiff
import tifffile

# %%
from PIL import Image
img = Image.open("/content/drive/MyDrive/Untitled.emf")
show(img)
pixels = img.load()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in squeeze(a, axis)
#    1538     try:
# -> 1539         squeeze = a.squeeze
#    1540     except AttributeError:
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in __getattr__(self, name)
#     528             return self._category
# --> 529         raise AttributeError(name)
#     530
#
# AttributeError: squeeze
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-bd3b9a701013> in <cell line: 3>()
#       1 from PIL import Image
#       2 img = Image.open("/content/drive/MyDrive/Untitled.emf")
# ----> 3 show(img)
#       4 pixels = img.load()
#
# ...
